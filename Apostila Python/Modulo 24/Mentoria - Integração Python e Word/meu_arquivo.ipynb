# %%
#!pip install python-docx

# %%
from docx import Document

# Criando o documento
documento = Document()

faturamento = 1000
# Aqui edita tudo que quiser no arquivo
texto = f"""Fala Felipe,

O faturamento da empresa ontem foi de R$ {faturamento:,.2f}

Tamo Junto Abs.
"""

paragrafo = documento.add_paragraph(texto)

# %% [markdown]
# ### Formatação

# %%
from docx.shared import Pt, RGBColor, Cm # Valores de formatação
from docx.enum.style import WD_STYLE_TYPE

paragrafo.style = documento.styles.add_style('EstiloDaniel', WD_STYLE_TYPE.PARAGRAPH)
paragrafo.style.font.name = 'Algerian'
paragrafo.style.font.size = Pt(15)
paragrafo.style.font.bold = True
paragrafo.style.font.italic = True
paragrafo.style.font.underline = True
paragrafo.style.font.color.rgb = RGBColor(255, 0, 0)

# %%
paragrafo = documento.add_paragraph('PS: A quantidade de produtos vendidos foi 10', 'EstiloDaniel')

# %%
# Implementando tudo que foi feito no documento
documento.save('Texto.docx')

# %% [markdown]
# ### Aproveitando um template do word

# %%
template = Document('Template.docx')

# %%
for estilo in template.styles:
    print(estilo)

# %%
paragrafo = template.add_paragraph('Contrato de Prestação de Servico', 'NovoEstiloABNT')
template.save('NovoArquivo.docx')

# %% [markdown]
# ### Adicionar texto com edição dentro do texto

# %%
from docx import Document

# Criando o documento
documento = Document()

faturamento = 1000
# Aqui edita tudo que quiser no arquivo
texto = f"""Fala Felipe,

O faturamento da empresa ontem foi de """

texto_final = "Tamo Junto Abs."

paragrafo = documento.add_paragraph(texto)
paragrafo.add_run(f'R$ {faturamento}').bold = True

paragrafo = documento.add_paragraph(texto_final)

documento.save('Texto.docx')

# %% [markdown]
# ### Controle de Margem e Seções

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# Criando o documento
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)
    
    
faturamento = 1000
# Aqui edita tudo que quiser no arquivo
texto = f"""Fala Felipe,

O faturamento da empresa ontem foi de R$ {faturamento:,.2f}

Tamo Junto Abs.
"""

paragrafo = documento.add_paragraph(texto)
paragrafo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save('Texto.docx')

# %% [markdown]
# ### Inserir imagem

# %%
# Criando o documento
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)
    
    
faturamento = 1000
# Aqui edita tudo que quiser no arquivo
texto = f"""Fala Felipe,

O faturamento da empresa ontem foi de R$ {faturamento:,.2f}

Tamo Junto Abs.
"""

paragrafo = documento.add_paragraph(texto)

imagem = documento.add_picture('imagem.png', width=Cm(5), height=Cm(5))

documento.save('Texto.docx')

# %% [markdown]
# ### Inserir tabela

# %%
documento = Document()

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

table = documento.add_table(rows=1, cols=3, style='Light Grid Accent 1')
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc


documento.save('Texto.docx')

# %% [markdown]
# ### Para verificar todos os estilos de um arquivo:

# %%
for estilo in documento.styles:
    print(estilo)

# %% [markdown]
# ### Adaptar um documento

# %%
from datetime import datetime

contrato = Document('Contrato.docx')

nome = 'Daniel'
item1 = 'Serviço de criação de planilhas'
item2 = 'Serviço de criação de software'
item3 = 'Serviço de análise de dados'

dicionario_valores = {
    'XXXX': nome,
    'YYYY': item1,
    'ZZZZ': item2,
    'WWWW': item3,
    'DD': str(datetime.now().day),
    'MM': str(datetime.now().month),
    'AAAA': str(datetime.now().year ),
}

for paragrafo in contrato.paragraphs:
    for placeholder in dicionario_valores:
        if placeholder in paragrafo.text:
            paragrafo.text = paragrafo.text.replace(placeholder, dicionario_valores[placeholder])

contrato.save('Contrato Atualizado.docx')
