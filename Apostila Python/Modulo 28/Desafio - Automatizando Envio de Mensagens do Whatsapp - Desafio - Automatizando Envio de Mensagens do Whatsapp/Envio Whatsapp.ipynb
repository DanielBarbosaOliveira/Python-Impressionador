# %% [markdown]
# ### Cuidados!
#
# 1. Whatsapp não gosta de nenhum tipo de automação
# 2. Isso pode dar merda, já to avisando
# 3. Isso não é o uso da API oficial do Whatsapp, o próprio whatsapp tem uma API oficial. Se o seu objetivo é fazer envio em massa ou criar aqueles robozinhos que respondem automaticamente no whatsapp, então use a API oficial
# 4. Meu objetivo é 100% educacional
#
# ### Dito isso, bora automatizar o envio de mensagens no Whatsapp
#
# - Vamos usar o Selenium (vídeo da configuração na descrição)
# - Temos 1 alternativa muito boa:
# - Usar o https://web.whatsapp.com/send?phone=numero&text=texto (mais fácil, mais seguro, mas mais demorado)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

navegador = webdriver.Chrome()
navegador.get("https://web.whatsapp.com")

while len(navegador.find_elements(By.ID, "pane-side")) < 1:
    time.sleep(1)
    
time.sleep(2)

# %%
# O whatsapp já carregou
import pandas as pd

tabela = pd.read_excel("Envios.xlsx")
display(tabela)
# Out:
#             nome                    mensagem                   arquivo  \
# 0  Diego Hashtag   E aí, fulano, tudo certo?                         N
# 1   Alon Hashtag    Coe fulano, bora surfar?                         N
# 2   Lira Hashtag  Viajou, fulano. Olha isso:  pythonimpressionador.png
#
#       telefone
# 0  65999088840
# 1  65999088840
# 2  65999088840

# %%
import urllib

for indice, linha in tabela.iterrows():
    nome = linha["nome"]
    mensagem = linha["mensagem"]
    arquivo = linha["arquivo"]
    telefone = ["telefone"]
    
    texto = mensagem.replace("fulano", nome)
    texto = urllib.parse.quote(texto)

    # enviar a mensagem
    link = f"https://web.whatsapp.com/send?phone={telefone}&text={texto}"
    
    navegador.get(link)
    # esperar a tela do whatsapp carregar -> espera um elemento que só existe na tela já carregada
    while len(navegador.find_elements(By.ID, "pane-side")) < 1:
        time.sleep(1)
    
    
    time.sleep(2)
    
    # Enviar a mensagem
    navegador.find_element(By.XPATH, '//*[@id="main"]/footer/div[1]/div/span/div/div/div/div[5]/div/span/div/button').click()
    time.sleep(2)
    break
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[29], line 24
#      20
#      21     time.sleep(2)
#      22
#      23     # Enviar a mensagem
# ---> 24     navegador.find_element(By.XPATH, '//*[@id="main"]/footer/div[1]/div/span/div/div/div/div[5]/div/span/div/button').click()
#      25     time.sleep(2)
#      26     break
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 28/Desafio - Automatizando Envio de Mensagens do Whatsapp - Desafio - Automatizando Envio de Mensagens do Whatsapp/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:899, in WebDriver.find_element(self, by, value)
#     896         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     897     return elements[0]
# --> 899 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 28/Desafio - Automatizando Envio de Mensagens do Whatsapp - Desafio - Automatizando Envio de Mensagens do Whatsapp/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:492, in WebDriver.execute(self, driver_command, params)
#     489 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     491 if response:
# --> 492     self.error_handler.check_response(response)
#     493     response["value"] = self._unwrap_value(response.get("value", None))
#     494     return response
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 28/Desafio - Automatizando Envio de Mensagens do Whatsapp - Desafio - Automatizando Envio de Mensagens do Whatsapp/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="main"]/footer/div[1]/div/span/div/div/div/div[5]/div/span/div/button"}
#   (Session info: chrome=150.0.7871.187); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 0   chromedriver                        0x0000000102a336fc chromedriver + 5945084
# 1   chromedriver                        0x00000001024d44e8 chromedriver + 312552
# 2   chromedriver                        0x000000010251d96c chromedriver + 612716
# 3   chromedriver                        0x000000010255cc94 chromedriver + 871572
# 4   chromedriver                        0x000000010251333c chromedriver + 570172
# 5   chromedriver                        0x00000001029f8a04 chromedriver + 5704196
# 6   chromedriver                        0x00000001029fc284 chromedriver + 5718660
# 7   chromedriver                        0x00000001029de880 chromedriver + 5597312
# 8   chromedriver                        0x00000001029fcb18 chromedriver + 5720856
# 9   chromedriver                        0x00000001029cf9f8 chromedriver + 5536248
# 10  chromedriver                        0x0000000102a2140c chromedriver + 5870604
# 11  chromedriver                        0x0000000102a2156c chromedriver + 5870956
# 12  chromedriver                        0x0000000102a33354 chromedriver + 5944148
# 13  libsystem_pthread.dylib             0x000000018e9d9c54 _pthread_start + 132
# 14  libsystem_pthread.dylib             0x000000018e9d4c18 thread_start + 4

# %%
link = f"https://web.whatsapp.com/send?phone={telefone}&text={texto}"
    
navegador.get(link)
