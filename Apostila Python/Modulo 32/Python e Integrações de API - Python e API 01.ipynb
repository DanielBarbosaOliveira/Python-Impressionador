# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos (como veremos no caso do SMS) vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json
from pprint import pprint

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dicionario = cotacoes.json()
pprint(cotacoes_dicionario)
# Out:
# {'ARS': {'ask': '0.00340459',
#          'bid': '0.00340457',
#          'code': 'ARS',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:37',
#          'high': '0.00343088',
#          'low': '0.00332329',
#          'name': 'Peso Argentino/Real Brasileiro',
#          'pctChange': '2.445768',
#          'timestamp': '1785776737',
#          'varBid': '0.000081'},
#  'AUD': {'ask': '3.57266',
#          'bid': '3.56429',
#          'code': 'AUD',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:02:49',
#          'high': '3.58221',
#          'low': '3.53361',
#          'name': 'Dólar Australiano/Real Brasileiro',
#          'pctChange': '-0.215399',
#          'timestamp': '1785776569',
#          'varBid': '-0.007694'},
#  'BTC': {'ask': '325477',
#          'bid': '325476',
#          'code': 'BTC',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:53',
#          'high': '326209',
#          'low': '317373',
#          'name': 'Bitcoin/Real Brasileiro',
#          'pctChange': '0.969',
#          'timestamp': '1785776753',
#          'varBid': '3124'},
#  'CAD': {'ask': '3.63637',
#          'bid': '3.62784',
#          'code': 'CAD',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:02:49',
#          'high': '3.6451',
#          'low': '3.59635',
#          'name': 'Dólar Canadense/Real Brasileiro',
#          'pctChange': '0.251744',
#          'timestamp': '1785776569',
#          'varBid': '0.00911'},
#  'CHF': {'ask': '6.29693',
#          'bid': '6.28216',
#          'code': 'CHF',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:02:49',
#          'high': '6.3166',
#          'low': '6.24119',
#          'name': 'Franco Suíço/Real Brasileiro',
#          'pctChange': '-0.007783',
#          'timestamp': '1785776569',
#          'varBid': '-0.000489'},
#  'CNY': {'ask': '0.75340965',
#          'bid': '0.752705',
#          'code': 'CNY',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:46',
#          'high': '0.75794244',
#          'low': '0.75164795',
#          'name': 'Yuan Chinês/Real Brasileiro',
#          'pctChange': '0.140632',
#          'timestamp': '1785776746',
#          'varBid': '0.001057'},
#  'DOGE': {'ask': '0.3589',
#           'bid': '0.3587',
#           'code': 'DOGE',
#           'codein': 'BRL',
#           'create_date': '2026-08-03 14:05:46',
#           'high': '0.3633',
#           'low': '0.3518',
#           'name': 'Dogecoin/Real Brasileiro',
#           'pctChange': '0',
#           'timestamp': '1785776746',
#           'varBid': '0'},
#  'ETH': {'ask': '9527.23',
#          'bid': '9526.24',
#          'code': 'ETH',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:48',
#          'high': '9686.07',
#          'low': '9317.84',
#          'name': 'Ethereum/Real Brasileiro',
#          'pctChange': '0.22',
#          'timestamp': '1785776748',
#          'varBid': '20.96'},
#  'EUR': {'ask': '5.85343',
#          'bid': '5.84693',
#          'code': 'EUR',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:50',
#          'high': '5.91261',
#          'low': '5.82343',
#          'name': 'Euro/Real Brasileiro',
#          'pctChange': '-0.169548',
#          'timestamp': '1785776750',
#          'varBid': '-0.00993'},
#  'GBP': {'ask': '6.85038',
#          'bid': '6.84635',
#          'code': 'GBP',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:46',
#          'high': '6.87285',
#          'low': '6.79804',
#          'name': 'Libra Esterlina/Real Brasileiro',
#          'pctChange': '0.093552',
#          'timestamp': '1785776746',
#          'varBid': '0.006399'},
#  'ILS': {'ask': '1.68',
#          'bid': '1.669',
#          'code': 'ILS',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:44',
#          'high': '1.68038',
#          'low': '1.649',
#          'name': 'Novo Shekel Israelense/Real Brasileiro',
#          'pctChange': '0.845923',
#          'timestamp': '1785776744',
#          'varBid': '0.014'},
#  'JPY': {'ask': '0.03250982',
#          'bid': '0.03249071',
#          'code': 'JPY',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:46',
#          'high': '0.03270202',
#          'low': '0.03211741',
#          'name': 'Iene Japonês/Real Brasileiro',
#          'pctChange': '0.949352',
#          'timestamp': '1785776746',
#          'varBid': '0.000306'},
#  'LTC': {'ask': '226',
#          'bid': '225.8',
#          'code': 'LTC',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:51',
#          'high': '229.8',
#          'low': '224',
#          'name': 'Litecoin/Real Brasileiro',
#          'pctChange': '-1.828',
#          'timestamp': '1785776751',
#          'varBid': '-4.2'},
#  'USD': {'ask': '5.0879',
#          'bid': '5.0827',
#          'code': 'USD',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:50',
#          'high': '5.0968',
#          'low': '5.05335',
#          'name': 'Dólar Americano/Real Brasileiro',
#          'pctChange': '0.074822',
#          'timestamp': '1785776750',
#          'varBid': '0.0038'},
#  'USDT': {'ask': '5.44397',
#           'bid': '5.04414',
#           'code': 'USD',
#           'codein': 'BRLT',
#           'create_date': '2026-08-03 14:05:54',
#           'high': '5.15353',
#           'low': '5.04047',
#           'name': 'Dólar Americano/Real Brasileiro Turismo',
#           'pctChange': '-1.390352',
#           'timestamp': '1785776754',
#           'varBid': '-0.07112'},
#  'XRP': {'ask': '5.517',
#          'bid': '5.516',
#          'code': 'XRP',
#          'codein': 'BRL',
#          'create_date': '2026-08-03 14:05:47',
#          'high': '5.574',
#          'low': '5.411',
#          'name': 'XRP/Real Brasileiro',
#          'pctChange': '-0.036',
#          'timestamp': '1785776747',
#          'varBid': '-0.002'}}

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin? (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
print(f'Dólar {cotacoes_dicionario["USD"]["bid"]}')
print(f'Euro {cotacoes_dicionario["EUR"]["bid"]}')
print(f'BTC {cotacoes_dicionario["BTC"]["bid"]}')
# Out:
# Dólar 5.0827
# Euro 5.84693
# BTC 325476

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
cotacoes_dolar30d = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacoes_dolar30d_dicionario = cotacoes_dolar30d.json()
#pprint(cotacoes_dolar30d_dicionario[2]["bid"])
lista_cotacoes_dolar = [float(item["bid"]) for item in cotacoes_dolar30d_dicionario]
pprint(lista_cotacoes_dolar)
# Out:
# [5.0913,
#  5.0789,
#  5.0736,
#  5.0774,
#  5.1271,
#  5.137,
#  5.1286,
#  5.0825,
#  5.0785,
#  5.097,
#  5.06537,
#  5.0877,
#  5.1051,
#  5.1207,
#  5.1047,
#  5.1139,
#  5.0908,
#  5.088,
#  5.148,
#  5.1079,
#  5.1064,
#  5.1339,
#  5.1631,
#  5.1709,
#  5.1436,
#  5.1844,
#  5.165,
#  5.222,
#  5.2206,
#  5.1746]

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %%
cotacoes_btc = requests.get(f"https://economia.awesomeapi.com.br/json/daily/BTC-BRL/300?start_date=20200101&end_date=20201031")
cotacoes_btc_dicionario = cotacoes_btc.json()
lista_cotacoes_btc = [float(item["bid"]) for item in cotacoes_btc_dicionario]
lista_cotacoes_btc.reverse()
pprint(lista_cotacoes_btc)
# Out:
# [28200.6,
#  29776.1,
#  29761.0,
#  29650.0,
#  31313.3,
#  33049.1,
#  32800.2,
#  32172.0,
#  33200.2,
#  32897.0,
#  33050.0,
#  33384.4,
#  36210.0,
#  36781.0,
#  36471.8,
#  37104.3,
#  37273.1,
#  36400.0,
#  36604.0,
#  36820.0,
#  36500.0,
#  35216.0,
#  35649.1,
#  35177.2,
#  35891.2,
#  37158.0,
#  38870.0,
#  39101.0,
#  39991.0,
#  39601.0,
#  39660.0,
#  39376.0,
#  40690.0,
#  41690.0,
#  42285.0,
#  42590.0,
#  43786.8,
#  42771.0,
#  44219.2,
#  45110.0,
#  44520.1,
#  44660.5,
#  43201.0,
#  43390.0,
#  42400.4,
#  44220.1,
#  42910.0,
#  42450.0,
#  42870.9,
#  42772.1,
#  43726.2,
#  42722.1,
#  41800.0,
#  39650.7,
#  40000.0,
#  39356.8,
#  39001.9,
#  38750.0,
#  40100.1,
#  39602.1,
#  40100.7,
#  42101.0,
#  42300.0,
#  41453.1,
#  38612.5,
#  38100.2,
#  37200.1,
#  38429.9,
#  25800.0,
#  28150.0,
#  27050.0,
#  27935.0,
#  25715.6,
#  27100.0,
#  27669.4,
#  32011.0,
#  31820.1,
#  32084.3,
#  30879.8,
#  32605.1,
#  34155.0,
#  33801.0,
#  33890.9,
#  33050.0,
#  32142.5,
#  31000.0,
#  33000.1,
#  32577.9,
#  33510.6,
#  34550.7,
#  35600.0,
#  35601.3,
#  35320.4,
#  37655.2,
#  37250.0,
#  37720.1,
#  37255.2,
#  36007.0,
#  36360.0,
#  35800.0,
#  35750.0,
#  35150.0,
#  37025.0,
#  36836.7,
#  37415.0,
#  37158.0,
#  36652.1,
#  36800.0,
#  38000.1,
#  40050.0,
#  41050.0,
#  41212.0,
#  41715.0,
#  43392.0,
#  43070.0,
#  46424.7,
#  46610.0,
#  47626.0,
#  47900.0,
#  48553.0,
#  48852.0,
#  49700.0,
#  52500.0,
#  57700.0,
#  52609.1,
#  52499.0,
#  49225.0,
#  49700.0,
#  51488.8,
#  54450.0,
#  56208.0,
#  53609.0,
#  54207.4,
#  55300.0,
#  55651.1,
#  55760.8,
#  54831.8,
#  51440.0,
#  51400.0,
#  51600.0,
#  49560.0,
#  49735.0,
#  47625.1,
#  49000.2,
#  51700.3,
#  50650.0,
#  51500.0,
#  50865.1,
#  53600.0,
#  54001.0,
#  49500.4,
#  50400.6,
#  48820.6,
#  49133.5,
#  48096.8,
#  48201.0,
#  49350.0,
#  47000.0,
#  48100.1,
#  47788.9,
#  47750.0,
#  48501.4,
#  49679.0,
#  49290.6,
#  50405.0,
#  49700.0,
#  49750.0,
#  49782.0,
#  50710.0,
#  49759.1,
#  49800.0,
#  49755.0,
#  49915.1,
#  49678.2,
#  49746.8,
#  49840.0,
#  49960.0,
#  49800.0,
#  49208.8,
#  48815.5,
#  48993.1,
#  48850.0,
#  49890.0,
#  49900.1,
#  50360.1,
#  49890.0,
#  49905.9,
#  49750.0,
#  49920.0,
#  50041.3,
#  50073.4,
#  49868.0,
#  49320.0,
#  49702.1,
#  49651.8,
#  49680.0,
#  49516.5,
#  49143.0,
#  49321.0,
#  49850.0,
#  49951.1,
#  50400.2,
#  50402.0,
#  55300.0,
#  56161.0,
#  57490.0,
#  57330.0,
#  58950.0,
#  61298.1,
#  58296.3,
#  59800.0,
#  59951.0,
#  61902.2,
#  63302.0,
#  63140.0,
#  63715.0,
#  63700.0,
#  65303.8,
#  62300.0,
#  63120.0,
#  63210.3,
#  63905.0,
#  64280.0,
#  64270.3,
#  67501.0,
#  66453.3,
#  65800.0,
#  66655.0,
#  65657.4,
#  66112.0,
#  66100.0,
#  66360.9,
#  63606.0,
#  64655.2,
#  63599.9,
#  63016.2,
#  62700.0,
#  63350.9,
#  64200.0,
#  64900.0,
#  61939.0,
#  55336.6,
#  56500.0,
#  54555.7,
#  55550.3,
#  55102.2,
#  54348.3,
#  55059.1,
#  55511.0,
#  55821.2,
#  55856.7,
#  55566.0,
#  56908.9,
#  57700.0,
#  58250.0,
#  57807.2,
#  59285.0,
#  59750.0,
#  59100.0,
#  57050.6,
#  57880.5,
#  57884.0,
#  59501.1,
#  59845.0,
#  59720.5,
#  59638.4,
#  60600.1,
#  60995.0,
#  60950.1,
#  60390.7,
#  60512.5,
#  60018.1,
#  60569.2,
#  60210.3,
#  59801.0,
#  60265.0,
#  61211.5,
#  61960.0,
#  62747.2,
#  62701.0,
#  63558.3,
#  63601.7,
#  64100.6,
#  65000.0,
#  64400.0,
#  64500.0,
#  64950.1,
#  66000.3,
#  66952.4,
#  71401.0,
#  72251.2,
#  72202.4,
#  73300.0,
#  73200.0,
#  73685.5,
#  77888.1,
#  76550.1,
#  77950.2,
#  78101.0,
#  79401.1]

# %% [markdown]
# #### Gráfico com as cotações do BitCoin

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(lista_cotacoes_btc, label="Cotação BTC")
plt.show()
