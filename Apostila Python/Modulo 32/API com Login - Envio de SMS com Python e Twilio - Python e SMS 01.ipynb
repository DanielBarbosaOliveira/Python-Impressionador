# %% [markdown]
# # Python e API com Login
#
# ### O 1º Passo de toda API com Login é criar uma conta e pegar suas credenciais
#
# ### No seu código, o 1º passo é sempre estabelecer a conexão com a API, usando seu login e suas credenciais
#
# - Como cada API é uma ferramenta diferente, cada uma delas pode exigir que você faça algum tipo de configuração, que vai estar explicada na API. No nosso caso, teremos que validar um número e criar um número de envio
#
# - Depois, usamos os métodos da API normalmente para fazer o que queremos. No nosso caso, enviar um SMS

# %% [markdown]
# #### 1. Vamos criar um login no Twilio
#
# https://www.twilio.com/docs/libraries/python

# %% [markdown]
# #### 2. Depois do Login, vamos pegar 3 informações:
#
# - ID da Conta
# - Token
# - Número de Envio

# %% [markdown]
# #### 3. Agora vamos validar um número porque no Twilio, enviar SMS para um número válido é de graça

# %% [markdown]
# #### 4. Agora podemos fazer o nosso código de acordo com as orientações do Twilio

# %%
from twilio.rest import Client

account_sid = "SEU_ACCOUNT_SID"
token = "Seu Token"

remetente = "+17372508034"
destino = "+5565999088840"

client = Client(account_sid, token)

message = client.messages.create(
    to=destino,
    from_=remetente,
    body="sms_appointment_reminders",
)
print(message.sid)
# Out:
# ---------------------------------------------------------------------------
# TwilioRestException                       Traceback (most recent call last)
# Cell In[5], line 11
#       7 destino = "+5565999088840"
#       8
#       9 client = Client(account_sid, token)
#      10
# ---> 11 message = client.messages.create(
#      12     to=destino,
#      13     from_=remetente,
#      14     body="Fala comigo",
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 32/.venv/lib/python3.12/site-packages/twilio/rest/api/v2010/account/message/__init__.py:871, in MessageList.create(self, to, status_callback, application_sid, max_price, provide_feedback, attempt, validity_period, force_delivery, content_retention, address_retention, smart_encoded, persistent_action, traffic_type, shorten_urls, schedule_type, send_at, send_as_mms, content_variables, risk_check, from_, fallback_from, messaging_service_sid, body, media_url, content_sid)
#     808 def create(
#     809     self,
#     810     to: str,
#    (...)    838     content_sid: Union[str, object] = values.unset,
#     839 ) -> MessageInstance:
#     840     """
#     841     Create the MessageInstance
#     842
#    (...)    869     :returns: The created MessageInstance
#     870     """
# --> 871     payload, _, _ = self._create(
#     872         to=to,
#     873         status_callback=status_callback,
#     874         application_sid=application_sid,
#     875         max_price=max_price,
#     876         provide_feedback=provide_feedback,
#     877         attempt=attempt,
#     878         validity_period=validity_period,
#     879         force_delivery=force_delivery,
#     880         content_retention=content_retention,
#     881         address_retention=address_retention,
#     882         smart_encoded=smart_encoded,
#     883         persistent_action=persistent_action,
#     884         traffic_type=traffic_type,
#     885         shorten_urls=shorten_urls,
#     886         schedule_type=schedule_type,
#     887         send_at=send_at,
#     888         send_as_mms=send_as_mms,
#     889         content_variables=content_variables,
#     890         risk_check=risk_check,
#     891         from_=from_,
#     892         fallback_from=fallback_from,
#     893         messaging_service_sid=messaging_service_sid,
#     894         body=body,
#     895         media_url=media_url,
#     896         content_sid=content_sid,
#     897     )
#     898     return MessageInstance(
#     899         self._version, payload, account_sid=self._solution["account_sid"]
#     900     )
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 32/.venv/lib/python3.12/site-packages/twilio/rest/api/v2010/account/message/__init__.py:804, in MessageList._create(self, to, status_callback, application_sid, max_price, provide_feedback, attempt, validity_period, force_delivery, content_retention, address_retention, smart_encoded, persistent_action, traffic_type, shorten_urls, schedule_type, send_at, send_as_mms, content_variables, risk_check, from_, fallback_from, messaging_service_sid, body, media_url, content_sid)
#     800 headers["Content-Type"] = "application/x-www-form-urlencoded"
#     802 headers["Accept"] = "application/json"
# --> 804 return self._version.create_with_response_info(
#     805     method="POST", uri=self._uri, data=data, headers=headers
#     806 )
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 32/.venv/lib/python3.12/site-packages/twilio/base/version.py:864, in Version.create_with_response_info(self, method, uri, params, data, headers, auth, timeout, allow_redirects)
#     845 """
#     846 Create a resource and return response metadata
#     847
#    (...)    852         - headers_dict: Response headers as a dictionary
#     853 """
#     854 response = self.request(
#     855     method,
#     856     uri,
#    (...)    862     allow_redirects=allow_redirects,
#     863 )
# --> 864 payload = self._parse_create(method, uri, response)
#     865 return payload, response.status_code, dict(response.headers or {})
#
# File ~/cursos/Python-Impressionador/Apostila Python/Modulo 32/.venv/lib/python3.12/site-packages/twilio/base/version.py:778, in Version._parse_create(self, method, uri, response)
#     774 """
#     775 Parse create response JSON
#     776 """
#     777 if response.status_code < 200 or response.status_code >= 300:
# --> 778     raise self.exception(method, uri, response, "Unable to create record")
#     780 return json.loads(response.text)
#
# TwilioRestException: HTTP 400 error: Unable to create record: Invalid template name. Trial accounts can only use predefined SMS templates.
