# %%
import pandas as pd

moedas = pd.DataFrame(['EUR', 'USD', 'BTC'], columns=['Moedas'])
print(moedas)
# Out:
#   Moedas
# 0    EUR
# 1    USD
# 2    BTC

# %%
moedas.to_excel('Moedas.xlsx', index=False)
